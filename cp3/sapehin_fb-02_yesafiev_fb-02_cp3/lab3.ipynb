# %%
import codecs
import numpy as np
import pandas as pd
import re

# %%
# Opening text for bigram frequency
text_file = codecs.open( "metro-2033.txt", "r", "utf_8_sig" )
file_no_spaces = codecs.open('text-no-spaces.txt', 'w', "utf_8_sig")

text = text_file.read()
text_file.close()

# %%
# Writing files cell
text = text.lower()
text = re.sub('[^а-я]', ' ', text)
text = re.sub('ъ', 'ь', text)
text = re.sub('ё', 'е', text)

text = re.sub('\s+', '', text)

file_no_spaces.write(text)
file_no_spaces.close()

# %%
def count_bigram_probs(alphab, txt):
    alphab_square = [i+j for i in alphab for j in alphab]

    probs = {}
    length = len(txt) - 1
    for bigram in alphab_square:
        probs[bigram] = txt.count(bigram)/length
    return probs

# %%
def count_bigram_probs_2(alphab, txt):
    alphab_square = [i+j for i in alphab for j in alphab]

    probs = {}
    length = int(len(txt)/2)
    for i in alphab_square:
        probs[i] = 0

    for i in range(0, len(txt), 2):
        if i < len(txt) - 1:
            probs[txt[i]+txt[i+1]] += 1

    probs = {k: v/length for k, v in probs.items()}
    return probs

# %%
def bigram_to_num(bigram, alphab):
    return alphab.index(bigram[0]) * len(alphab) + alphab.index(bigram[1])

# %%
def prohibited_bigrams(bigrams):
    l = []
    for bigram in bigrams:
        if bigrams[bigram] == 0:
            l.append(bigram)
    return l

# %%
def sort_dict(dicti):
    return dict(sorted(dicti.items(), key=lambda item: item[1]))

# %%
alphabet = list('абвгдежзийклмнопрстуфхцчшщыьэюя')
bigram_probs = count_bigram_probs(alphabet, text)
# Out:
# {'аа': 0.0005100867514446341,
#  'аб': 0.0013687939445240903,
#  'ав': 0.0051730380620128484,
#  'аг': 0.0012843911007598702,
#  'ад': 0.0027449272667668086,
#  'ае': 0.0015510551578700148,
#  'аж': 0.0014299554255126556,
#  'аз': 0.0042519461583250566,
#  'аи': 0.0012464709825469598,
#  'ай': 0.0007522862161593526,
#  'ак': 0.0057051429466133665,
#  'ал': 0.009893481164710314,
#  'ам': 0.0045137172969561155,
#  'ан': 0.007579130724103006,
#  'ао': 0.0011535055314443406,
#  'ап': 0.0028342230290101136,
#  'ар': 0.005908199063495403,
#  'ас': 0.00581156392353347,
#  'ат': 0.006399937370643468,
#  'ау': 0.0004905150775282933,
#  'аф': 0.0001480107839923279,
#  'ах': 0.0012061044050945067,
#  'ац': 0.0003021377160835123,
#  'ач': 0.0016317883127749209,
#  'аш': 0.0010336290287067528,
#  'ащ': 0.000445255581596755,
#  'аы': 0.0,
#  'аь': 0.0,
#  'аэ': 0.00034739721201505064,
#  'аю': 0.0011021298874139458,
#  'ая': 0.002766945399922692,
#  'ба': 0.0007681882012163795,
# ...

# %%
print(sort_dict(bigram_probs))
most_orig = ['то', 'ст', 'на', 'но', 'не', 'по', 'от']
# Out:
# {'аы': 0.0, 'аь': 0.0, 'бй': 0.0, 'бф': 0.0, 'вй': 0.0, 'гй': 0.0, 'гы': 0.0, 'гь': 0.0, 'гю': 0.0, 'дй': 0.0, 'еы': 0.0, 'еь': 0.0, 'жй': 0.0, 'жц': 0.0, 'жш': 0.0, 'жщ': 0.0, 'жы': 0.0, 'жю': 0.0, 'зй': 0.0, 'зщ': 0.0, 'иь': 0.0, 'йй': 0.0, 'йы': 0.0, 'йь': 0.0, 'кй': 0.0, 'кы': 0.0, 'кь': 0.0, 'лй': 0.0, 'мй': 0.0, 'нй': 0.0, 'оы': 0.0, 'оь': 0.0, 'пг': 0.0, 'пж': 0.0, 'пй': 0.0, 'пм': 0.0, 'пф': 0.0, 'пх': 0.0, 'пщ': 0.0, 'пю': 0.0, 'рй': 0.0, 'сй': 0.0, 'сщ': 0.0, 'тй': 0.0, 'уы': 0.0, 'уь': 0.0, 'фб': 0.0, 'фв': 0.0, 'фж': 0.0, 'фз': 0.0, 'фй': 0.0, 'фх': 0.0, 'фц': 0.0, 'фш': 0.0, 'фщ': 0.0, 'фэ': 0.0, 'фю': 0.0, 'хй': 0.0, 'хы': 0.0, 'хь': 0.0, 'цй': 0.0, 'цц': 0.0, 'цщ': 0.0, 'ць': 0.0, 'ця': 0.0, 'чй': 0.0, 'чц': 0.0, 'чщ': 0.0, 'чы': 0.0, 'чю': 0.0, 'шз': 0.0, 'шй': 0.0, 'шф': 0.0, 'шш': 0.0, 'шщ': 0.0, 'шы': 0.0, 'шя': 0.0, 'щд': 0.0, 'щж': 0.0, 'щз': 0.0, 'щй': 0.0, 'щл': 0.0, 'щп': 0.0, 'щс': 0.0, 'щх': 0.0, 'щц': 0.0, 'щч': 0.0, 'щш': 0.0, 'щы': 0.0, 'щю': 0.0, 'щя': 0
# ...

# %%
prohibited_bigrams(bigram_probs)
# Out:
# ['аы',
#  'аь',
#  'бй',
#  'бф',
#  'вй',
#  'гй',
#  'гы',
#  'гь',
#  'гю',
#  'дй',
#  'еы',
#  'еь',
#  'жй',
#  'жц',
#  'жш',
#  'жщ',
#  'жы',
#  'жю',
#  'зй',
#  'зщ',
#  'иь',
#  'йй',
#  'йы',
#  'йь',
#  'кй',
#  'кы',
#  'кь',
#  'лй',
#  'мй',
#  'нй',
#  'оы',
#  'оь',
#  'пг',
#  'пж',
#  'пй',
#  'пм',
#  'пф',
#  'пх',
#  'пщ',
#  'пю',
#  'рй',
#  'сй',
#  'сщ',
#  'тй',
#  'уы',
#  'уь',
#  'фб',
#  'фв',
#  'фж',
#  'фз',
#  'фй',
#  'фх',
#  'фц',
#  'фш',
#  'фщ',
#  'фэ',
#  'фю',
#  'хй',
#  'хы',
#  'хь',
#  'цй',
#  'цц',
#  'цщ',
#  'ць',
#  'ця',
#  'чй',
#  'чц',
#  'чщ',
#  'чы',
#  'чю',
#  'шз',
#  'шй',
#  'шф',
#  'шш',
#  'шщ',
#  'шы',
#  'шя',
#  'щд',
#  'щж',
#  'щз',
#  'щй',
#  'щл',
#  'щп',
#  'щс',
#  'щх',
#  'щц',
#  'щч',
#  'щш',
#  'щы',
#  'щю',
#  'щя',
#  'ыь',
#  'ьй',
#  'ьы',
#  'ьь',
#  'эа',
#  'эе',
#  'эж',
#  'эо',
#  'эу',
#  'эц',
#  'эщ',
#  'эы',
#  'эь',
#  'эю',
#  'эя',
#  'юй',
#  'юы',
#  'юь',
#  'яы']

# %%
var_file = codecs.open("./variant.utf8/01.txt", "r", "utf_8_sig")
var_text = var_file.read()
var_file.close()
var_text = re.sub('[^а-я]', '', var_text)
var_text
# Out:
# 'лквдвдьышкрбызякиабшачрнвязарчтчлчькзтманэмнязяыбштрпнхтрхрнзтжккысечамнмпывйвфяжтинфвйвйвсжнпчнмпгущзкыфвйвутсюцзкыкынмотзщбйьыбшхолуычгкицепзкианьуыфллфтыраючькиащзтыфэнкйяпезтнкжккысечамнмпжэпаычйдбцвсшчмтшслаиятасзбчжйьыбшывлтйэзщбцпцмпщрифкздтеэкктщзархрчосйпрйжклечаккяжюыщяояфскчбяызрчйзчвгзжзычэявсшчтщлжочшызюшхачрнтмнкуфйзбчечвпчнотмнктхеотнчняцзбшрчычбчнкицгщлчькевочфыщяцзреотйсфтбйщялчдечамнмпйарчтчццзтьярняыхашхаытыыздсепцяьаючшзбшзтжмсяачрнвязаозеарчэяицкятчрогцфэкыпэзтйпчаэеэявахыдпдойдкрмпбцмвеэлжочрчщтецрнбяшкуэтыычлчокбцккузбнинепжвининачрнсджяцццаиятчщтецрнбяшквдиабцотияьаццйвычфткюмпьяэяддаьччшызюсяуядсяжутрхбцшчрнфэтзткзтцтеялчакиажчштзмнксябяешщтецрнбяшкуэчцеопнхоьяючбястзырзгьфлуфжмнкецььэтнкфячащжвжяымэвячатьияцзоеязднеэмэйкоевсщыяыяажвычцяучпяэязяшкинвдэякзюнзтмакырцсоушрнецчнкяуялжочознкьызаццнкяжсгмпчнвдепйдрчкеэярклнвцычпрычжкнпщюрчньаччквсеокяяорнбччнйцнбшзикзчшклзпеепаопниашчеквдзеязэгцеккьызаццнкшчрнхкнчьхвсфэиащзинэяьяцзчцычжтмэывйвщтецрнбяшктфбйьыемтщц
# ...

# %%
print(sort_dict(count_bigram_probs_2(alphabet, var_text)))
most_var = ['рн', 'ыч', 'нк', 'цз', 'иа', 'тч', 'фт']
# Out:
# {'аб': 0.0, 'ав': 0.0, 'аг': 0.0, 'ад': 0.0, 'ае': 0.0, 'аж': 0.0, 'аз': 0.0, 'аи': 0.0, 'ай': 0.0, 'ал': 0.0, 'ан': 0.0, 'ап': 0.0, 'ар': 0.0, 'ат': 0.0, 'ау': 0.0, 'аф': 0.0, 'ах': 0.0, 'ац': 0.0, 'аш': 0.0, 'ащ': 0.0, 'аю': 0.0, 'ая': 0.0, 'ба': 0.0, 'бб': 0.0, 'бв': 0.0, 'бг': 0.0, 'бд': 0.0, 'бе': 0.0, 'бж': 0.0, 'бз': 0.0, 'би': 0.0, 'бл': 0.0, 'бм': 0.0, 'бо': 0.0, 'бп': 0.0, 'бс': 0.0, 'бу': 0.0, 'бф': 0.0, 'бх': 0.0, 'бщ': 0.0, 'бы': 0.0, 'бю': 0.0, 'вб': 0.0, 'вв': 0.0, 'вг': 0.0, 'ве': 0.0, 'ви': 0.0, 'вк': 0.0, 'вл': 0.0, 'вм': 0.0, 'вн': 0.0, 'во': 0.0, 'вр': 0.0, 'вт': 0.0, 'ву': 0.0, 'вф': 0.0, 'вх': 0.0, 'вч': 0.0, 'вш': 0.0, 'вщ': 0.0, 'вэ': 0.0, 'вю': 0.0, 'га': 0.0, 'гб': 0.0, 'гв': 0.0, 'гг': 0.0, 'гд': 0.0, 'гж': 0.0, 'ги': 0.0, 'гй': 0.0, 'гл': 0.0, 'гп': 0.0, 'гр': 0.0, 'гт': 0.0, 'гф': 0.0, 'гх': 0.0, 'гч': 0.0, 'гэ': 0.0, 'гю': 0.0, 'да': 0.0, 'дб': 0.0, 'дв': 0.0, 'дг': 0.0, 'дж': 0.0, 'ди': 0.0, 'дл': 0.0, 'дм': 0.0, 'др': 0.0, 'ду': 0.0, 'дх': 0.0, 'дц': 0
# ...

# %%
def get_variants(orig, ciphered):
    variants = [((orig[0],ciphered[0]), (orig[1],ciphered[2]))]
    for i1 in range(len(orig)):
        for j1 in range(len(ciphered)):
            for i2 in range(len(orig)):
                for j2 in range(len(ciphered)):
                    if i1 == i2 or j1 == j2:
                        continue
                    x1y1 = (orig[i1], ciphered[j1])
                    x2y2 = (orig[i2], ciphered[j2])
                    if (x2y2, x1y1) in variants:
                        continue
                    variants.append((x1y1, x2y2))
    return variants

# %%
def gcdExtended(a, m):
    if a == 0 :
        return m, 0, 1
    gcd, x1, y1 = gcdExtended(m % a, a)
    x = y1 - (m // a) * x1
    y = x1
    return gcd,x,y

# %%
def inverseModulo(a, m):
    gcd, x, y = gcdExtended(a, m)
    if gcd == 1:
        return (x % m + m) % m
    else:
        return -1

# %%
def get_b(x, y, a, m2):
    return (y - a*x) % m2

# %%
def solve_equation(a, b, m2):
    a, b = a % m2, b % m2
    gcd, x, y = gcdExtended(a, m2)  # НСД  a і m
    ans = []
    if gcd == 1: # single root
        ans.append((inverseModulo(a, m2) * b) % m2)
        return ans

    if b % gcd != 0:  # no roots
        return ans

    a, b, m = a // gcd, b // gcd, m2 // gcd
    ans.append((solve_equation(a, b, m2)[0]))
    for i in range(1, d):
        ans.append(ans[-1] + m)
    return ans

# %%
def get_pos_roots(most_ciph):
    a_b_variants = []
    variants = get_variants(most_orig, most_ciph)
    for variant in variants:
        m = len(alphabet)
        y1 = bigram_to_num(variant[0][1], alphabet)
        y2 = bigram_to_num(variant[1][1], alphabet)
        x1 = bigram_to_num(variant[0][0], alphabet)
        x2 = bigram_to_num(variant[1][0], alphabet)

        x_d = (x1 - x2) % (m*m)
        y_d = (y1 - y2) % (m*m)

        print(y_d, solve_equation(x_d, y_d, m*m), x_d)

        # b = get_b(x1, y1, a, m*m)
        # if (a, b) in a_b_variants:
        #     continue
        # a_b_variants.append((a, b))
    a_b_variants = list(dict.fromkeys(a_b_variants))
    return a_b_variants

# %%
def decipher_bigram(bigram, a, b, alphab):
    m2 = len(alphab)**2
    n = bigram_to_num(bigram, alphab)
    a_inverse = inverseModulo(a, m2)
    return a_inverse*(n - b) % m2

def decipher(txt, a, b, alphab):
    alphab_square = [i+j for i in alphab for j in alphab]
    num_to_bigram = {}

    for bigram in alphab_square:
        num_to_bigram[bigram_to_num(bigram, alphab)] = bigram

    deciphered = ''

    for i in range(0, len(txt), 2):
        if i < len(txt) - 1:
            bigram = txt[i]+txt[i+1]
            bigram_d = decipher_bigram(bigram, a, b, alphab)
            deciphered += num_to_bigram[bigram_d]

    return deciphered

# %%
def has_prohibited(text):
    prohibited = [x + 'ь' for x in 'аеуыияьоэюй']
    for pr in prohibited:
        if pr in text:
            return True
    return False

# %%
var_a_b_variants = get_pos_roots(most_var)
for a, b in var_a_b_variants:
    d = decipher(var_text, a, b, alphabet)
    if has_prohibited(d):
        continue
    print(a, b)
    print(d[:100])

# %%
var_a_b_variants = get_pos_roots(most_var)
# Out:
# 96 [178] 27
# 641 [178] 27
# 96 [178] 27
# 781 [178] 27
# 261 [178] 27
# 889 [178] 27
# 832 [178] 27
# 641 [-290] 169
# 96 [-290] 169
# 781 [-290] 169
# 261 [-290] 169
# 889 [-290] 169
# 832 [-290] 169
# 641 [] 155
# 96 [] 155
# 781 [] 155
# 261 [] 155
# 889 [] 155
# 832 [] 155
# 641 [-334] 164
# 96 [-334] 164
# 781 [-334] 164
# 261 [-334] 164
# 889 [-334] 164
# 832 [-334] 164
# 641 [] 93
# 96 [] 93
# 781 [] 93
# 261 [] 93
# 889 [] 93
# 832 [] 93
# 641 [-8] 120
# 96 [-8] 120
# 781 [-8] 120
# 261 [-8] 120
# 889 [-8] 120
# 832 [-8] 120
# 320 [178] 27
# 416 [178] 27
# 140 [178] 27
# 581 [178] 27
# 248 [178] 27
# 191 [178] 27
# 320 [-290] 169
# 416 [-290] 169
# 140 [-290] 169
# 581 [-290] 169
# 248 [-290] 169
# 191 [-290] 169
# 320 [] 155
# 416 [] 155
# 140 [] 155
# 581 [] 155
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-144-ef4087000711> in <module>
# ...
